# %%
import pandas as pd

df = pd.read_excel('Shortlisted Teams.xlsx')
df
# Out:
#    Team ID FULL NAME ( Team Leader )  Contact Number ( Team Leader )  \
# 0     TH01           D.v.n.kameswari                      8639802518
# 1     TH02         VIRAJ KUMAR SINGH                      9939890224
# 2     TH03      Aleena Sara Varghese                      9072096822
# 3     TH04            HARIPRAKAASH N                      9600899028
# 4     TH05                 Vignesh M                      9843578129
# 5     TH06                  SUJITH S                      9842020721
# 6     TH07              Sanjana jain                      9318364350
# 7     TH08               CHETHAN N C                      9483166645
# 8     TH09           Nikhil Bhardwaj                      9439431700
# 9     TH10             PREETHIKA N C                      8248369519
# 10    TH11           SUJITHKUMAR M A                      6382458470
# 11    TH12               Vicky Kumar                      8239957923
# 12    TH13                    Simran                      8427945004
# 13    TH14             Ankita pathak                      7096455907
# 14    TH15              Nishant Giri                      8135074940
# 15    TH16              Ashish Kumar                      7568441216
# 16    TH17            Muktida Pandey                      9473854490
# 17    TH18       Nihar Jyoti Basisth                      8638769969
# 18    TH19           Dhritiraj Borah                      6003463542
# 19    TH20              Sameer Patel                      9920027975
#
#    College Name ( All team members must belong from same College )  \
# 0                Vidya Jyothi institute of technology
# 1   G.V. Acharya Institute of Engineering and Tech...
# 2         Muthoot Institute of Technology and Science
# 3               Bannari Amman Institute of Technology
# 4         Government College of Technology,Coimbatore
# 5               Bannari Amman Institute of Technology
# 6                            ABES Engineering College
# 7                    YENEPOYA INSTITUTE OF TECHNOLOGY
# 8        Great Lakes Institute of Management, Gurgaon
# 9               BANNARI AMMAN INSTITUTE OF TECHNOLOGY
# 10                          PSG College of Technology
# 11  Rajasthan Institution of Engineering and Techn...
# 12     Thapar Institute of Engineering and Technology
# 13  Rajasthan institute of engineering and technology
# 14  Kalinga Institute of Industrial Technology, Bh...
# 15  Rajasthan Institute of Engineering and Technology
# 16  Rajasthan Institute of Engineering and Technol...
# 17           National Institute of Technology Silchar
# 18          National Institute of Technology, Silchar
# 19                  KJ Somaiya College of Engineering
#
#              Team Name          EMAIL ID ( Team Leader )  \
# 0           Cocokasaya           kameswari2558@gmail.com
# 1               Torque            viraj.ks2001@gmail.com
# 2                 Aura             aleenasarav@gmail.com
# 3             Gagnants  hariprakaash.cb20@bitsathy.ac.in
# 4                Karna          vignesh3035465@gmail.com
# 5        Breaking Code        sujith.cs19@bitsathy.ac.in
# 6         Tech Bug 404        sanjana1998.jain@gmail.com
# 7   Yenground breakers            chethannc412@gmail.com
# 8                 Noor  nikhil.pgdm22g@greatlakes.edu.in
# 9      Numeric0_0Nerds     preethika.ec18@bitsathy.ac.in
# 10            Team KNK           masujithkumar@gmail.com
# 11   Boolean Freebirds         imvickykumar999@gmail.com
# 12           Volunesia         simranvolunesia@gmail.com
# 13        Technothorns         ankitapathak263@gmail.com
# 14       The Grandsons          nishantgiri.20@gmail.com
# 15           Cyberpunk       ashish99anonymous@gmail.com
# 16           TheTitans               muktida02@gmail.com
# 17    Unnamed Creators           nihar_ug@cse.nits.ac.in
# 18      The Plausibles       dhritiraj_ug@ece.nits.ac.in
# 19        Tech Pirates      sameer.patel201999@gmail.com
#
#      Full Name ( Member 1 ) Contact Number ( Member 1 )  \
# 0           D.v.n.kameswari                  8639802518
# 1         VIRAJ KUMAR SINGH                  9939890224
# 2             Harsha Daniel                  9188720294
# 3            PAUL DANIEL J                   7010935411
# 4                 Vignesh M                  9843578129
# 5                  SUJITH S                  9842020721
# 6                 Astha Rai                  7355287158
# 7                   Meghana                6363 836 781
# 8             Apoorva Verma                  7838381050
# 9                 BRUNDHA K                  6383616023
# 10        Viboosithasri N S                  9080503632
# 11            Ankit Malpani                  7727874136
# 12               Mehak Puri                  8264867510
# 13                Abu salim                  9973916664
# 14              Faizan Alam                  8210410103
# 15           sagar Jahangid                  8058771157
# 16           Vinay Jagetiya                  9521826100
# 17  Partha Pratim Choudhury                  7636890073
# 18              Jitul Teron                 70860 54393
# 19              Mittal Jain                  7506694479
#
#    Full Name ( Member 2 ) Contact Number ( Member 2 ) Full Name ( Member 3 )  \
# 0                 M.divya                         NaN              K.vasanth
# 1            ANKUSH VARMA                  9769288758                    NaN
# 2               Sreeram M                  6238042784              Sindhoora
# 3           MAHESHWAR S K                  8667420661       GOKULA PRASATH M
# 4               Praveen S                  9600435731                    NaN
# 5             SURENDHAR S                  7868984569      RANJITH KUMAR J N
# 6            Ishika Verma                  9560892392                    NaN
# 7                     NaN                         NaN                    NaN
# 8                     NaN                         NaN                    NaN
# 9                       -                           -                      -
# 10             Samritha D                  9677756189      Gowtham Easwar K
# 11      Anil puri Goswami                  9462308160                    NaN
# 12                    NaN                         NaN                    NaN
# 13         Aman srivastav                  7571948505         Jitendra singh
# 14                    NaN                         NaN                    NaN
# 15            Ayush Saini                         NaN         Mahipal pareek
# 16           Jhalak Salvi                  7733811120           Naman Mathur
# 17          Manish Sharma                  8812090429           Eisha Halder
# 18        Trishanku Sarma                 84862 41192           Shivam Kumar
# 19            Sarvesh Pai                  9920266494          Jignesh Nagda
#
#    Contact Number ( Member 3 )
# 0                          NaN
# 1                          NaN
# 2                   8089396813
# 3                   6374509979
# 4                          NaN
# 5                   6379812633
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                            -
# 10                  9486600023
# 11                         NaN
# 12                         NaN
# 13                  8104444443
# 14                         NaN
# 15                         NaN
# 16                  8955019949
# 17                  8638397302
# 18                6306 871 885
# 19                  8767670405

# %%
list(df['FULL NAME ( Team Leader )'])
# Out:
# ['D.v.n.kameswari',
#  'VIRAJ KUMAR SINGH',
#  'Aleena Sara Varghese',
#  'HARIPRAKAASH N',
#  'Vignesh M',
#  'SUJITH S',
#  'Sanjana jain',
#  'CHETHAN N C',
#  'Nikhil Bhardwaj',
#  'PREETHIKA N C',
#  'SUJITHKUMAR M A',
#  'Vicky Kumar',
#  'Simran',
#  'Ankita pathak',
#  'Nishant Giri',
#  'Ashish Kumar',
#  'Muktida Pandey',
#  'Nihar Jyoti Basisth',
#  'Dhritiraj Borah',
#  'Sameer Patel']

# %%
list(df['College Name ( All team members must belong from same College )'])
# Out:
# ['Vidya Jyothi institute of technology',
#  'G.V. Acharya Institute of Engineering and Technology',
#  'Muthoot Institute of Technology and Science',
#  'Bannari Amman Institute of Technology',
#  'Government College of Technology,Coimbatore',
#  'Bannari Amman Institute of Technology',
#  'ABES Engineering College',
#  'YENEPOYA INSTITUTE OF TECHNOLOGY',
#  'Great Lakes Institute of Management, Gurgaon',
#  'BANNARI AMMAN INSTITUTE OF TECHNOLOGY',
#  'PSG College of Technology',
#  'Rajasthan Institution of Engineering and Technology, Jaipur',
#  'Thapar Institute of Engineering and Technology',
#  'Rajasthan institute of engineering and technology',
#  'Kalinga Institute of Industrial Technology, Bhubaneswar',
#  'Rajasthan Institute of Engineering and Technology',
#  'Rajasthan Institute of Engineering and Technology, Jaipur',
#  'National Institute of Technology Silchar',
#  'National Institute of Technology, Silchar',
#  'KJ Somaiya College of Engineering']

# %%
list(df['EMAIL ID ( Team Leader )'])
# Out:
# ['kameswari2558@gmail.com',
#  'viraj.ks2001@gmail.com',
#  'aleenasarav@gmail.com',
#  'hariprakaash.cb20@bitsathy.ac.in',
#  'vignesh3035465@gmail.com',
#  'sujith.cs19@bitsathy.ac.in',
#  'sanjana1998.jain@gmail.com',
#  'chethannc412@gmail.com',
#  'nikhil.pgdm22g@greatlakes.edu.in',
#  'preethika.ec18@bitsathy.ac.in',
#  'masujithkumar@gmail.com',
#  'imvickykumar999@gmail.com',
#  'simranvolunesia@gmail.com',
#  'ankitapathak263@gmail.com',
#  'nishantgiri.20@gmail.com',
#  'ashish99anonymous@gmail.com',
#  'muktida02@gmail.com',
#  'nihar_ug@cse.nits.ac.in',
#  'dhritiraj_ug@ece.nits.ac.in',
#  'sameer.patel201999@gmail.com']

# %%
# # https://drive.google.com/drive/folders/1VVF-K5QqWQcvtnBZYpQAT6jgb7HOmgCf?usp=sharing

# from PIL import Image, ImageDraw, ImageFont
# import pandas as pd
# import os

# df = pd.read_excel('Shortlisted Teams.xlsx')
# namelist = list(df['FULL NAME ( Team Leader )'])
# collegelist = list(df['College Name ( All team members must belong from same College )'])
# font = ImageFont.truetype('arial.ttf',40)

# for i in range(len(df)):
#     img = Image.open('Certificate.png')
#     draw = ImageDraw.Draw(img)

#     name = namelist[i]
#     college = collegelist[i]
#     text = f'''

#     This is to certify that
#     "{name}"

#     student of
#     "{college}"

#     has participated in HACKRIETJ-2021
#     which held on 26/6/2021 by
#     "Rajasthan Institute of Engineering and Technology, Jaipur".
#     '''

#     draw.text(xy=(470,530),
#             text='{}'.format(text),
#             fill=(0,0,0),
#             align='center',
#             font=font)

#     img.save('pictures/{}.png'.format(f'{name}'))

# %%
df['Full Name ( Member 1 )']
# Out:
# 0             D.v.n.kameswari
# 1           VIRAJ KUMAR SINGH
# 2               Harsha Daniel
# 3              PAUL DANIEL J
# 4                   Vignesh M
# 5                    SUJITH S
# 6                   Astha Rai
# 7                     Meghana
# 8               Apoorva Verma
# 9                   BRUNDHA K
# 10          Viboosithasri N S
# 11              Ankit Malpani
# 12                 Mehak Puri
# 13                  Abu salim
# 14                Faizan Alam
# 15             sagar Jahangid
# 16             Vinay Jagetiya
# 17    Partha Pratim Choudhury
# 18                Jitul Teron
# 19                Mittal Jain
# Name: Full Name ( Member 1 ), dtype: object

# %%
df['Full Name ( Member 2 )']
# Out:
# 0               M.divya
# 1          ANKUSH VARMA
# 2             Sreeram M
# 3         MAHESHWAR S K
# 4             Praveen S
# 5           SURENDHAR S
# 6          Ishika Verma
# 7                   NaN
# 8                   NaN
# 9                     -
# 10           Samritha D
# 11    Anil puri Goswami
# 12                  NaN
# 13       Aman srivastav
# 14                  NaN
# 15          Ayush Saini
# 16         Jhalak Salvi
# 17        Manish Sharma
# 18      Trishanku Sarma
# 19          Sarvesh Pai
# Name: Full Name ( Member 2 ), dtype: object

# %%
m3 = list(df['Full Name ( Member 3 )'])
m3
# Out:
# ['K.vasanth',
#  nan,
#  'Sindhoora',
#  'GOKULA PRASATH M',
#  nan,
#  'RANJITH KUMAR J N',
#  nan,
#  nan,
#  nan,
#  '-',
#  'Gowtham Easwar K ',
#  nan,
#  nan,
#  'Jitendra singh',
#  nan,
#  'Mahipal pareek',
#  'Naman Mathur',
#  'Eisha Halder',
#  'Shivam Kumar',
#  'Jignesh Nagda']

# %%
type(m3[1]), m3[1]
# Out:
# (float, nan)

# %%
type(m3[9]), m3[9]
# Out:
# (str, '-')

# %%
type(m3[3]), m3[3]
# Out:
# (str, 'GOKULA PRASATH M')

# %%
float('nan')
# Out:
# nan
